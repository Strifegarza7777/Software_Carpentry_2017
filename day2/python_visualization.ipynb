# %%
import pygal

# %%
from IPython.display import SVG

# %%
import pandas

# %%
pygal
# Out:
# <module 'pygal' from 'C:\Anaconda2\lib\site-packages\pygal\__init__.pyc'>

# %%
pandas
# Out:
# <module 'pandas' from 'C:\Anaconda2\lib\site-packages\pandas\__init__.pyc'>

# %%
import pandas as pd

# %%
health_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ef47f7ddff52> in <module>()
# ----> 1 health_data.head()
#
# NameError: name 'health_data' is not defined

# %%
health_data = pd.read_csv('Dem_Health_Full.txt' , sep='\t')

# %%
health_data.head()
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
# 2  Barbour    AL                  32     22.1               7.1     10.3
# 3     Bibb    AL                  35     16.8               9.8     14.8
# 4   Blount    AL                  86     11.9               9.0     14.4
#
#    Total_Births  Total_Deaths
# 0          3048          1867
# 1          5471          4388
# 2          1835          1538
# 3          2801          2012
# 4          3318          2453

# %%
help(health_data)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
dir(health_data)
# Out:
# ['County',
#  'Infant_Mortality',
#  'Population_Density',
#  'Poverty',
#  'State',
#  'Suicide',
#  'T',
#  'Total_Births',
#  'Total_Deaths',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
health_data['State']
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AL
# 16      AL
# 17      AL
# 18      AL
# 19      AL
# 20      AL
# 21      AL
# 22      AL
# 23      AL
# 24      AL
# 25      AL
# 26      AL
# 27      AL
# 28      AL
# 29      AL
#         ..
# 3111    WI
# 3112    WI
# 3113    WI
# 3114    WI
# 3115    WI
# 3116    WI
# 3117    WI
# 3118    WY
# 3119    WY
# 3120    WY
# 3121    WY
# 3122    WY
# 3123    WY
# 3124    WY
# 3125    WY
# 3126    WY
# 3127    WY
# 3128    WY
# 3129    WY
# 3130    WY
# 3131    WY
# 3132    WY
# 3133    WY
# 3134    WY
# 3135    WY
# 3136    WY
# 3137    WY
# 3138    WY
# 3139    WY
# 3140    WY
# Name: State, dtype: object

# %%
health_data[['State','Poverty']]
# Out:
#      State  Poverty
# 0       AL     10.4
# 1       AL     10.2
# 2       AL     22.1
# 3       AL     16.8
# 4       AL     11.9
# 5       AL     26.2
# 6       AL     20.0
# 7       AL     16.4
# 8       AL     16.2
# 9       AL     15.2
# 10      AL     14.9
# 11      AL     18.7
# 12      AL     19.2
# 13      AL     14.0
# 14      AL     14.0
# 15      AL     13.7
# 16      AL     14.0
# 17      AL     22.0
# 18      AL     13.4
# 19      AL     17.5
# 20      AL     17.6
# 21      AL     13.3
# 22      AL     15.8
# 23      AL     25.0
# 24      AL     15.1
# 25      AL     12.5
# 26      AL     18.6
# 27      AL     15.7
# 28      AL     16.1
# 29      AL     17.4
# ...    ...      ...
# 3111    WI      9.7
# 3112    WI      4.6
# 3113    WI      4.1
# 3114    WI      7.4
# 3115    WI      9.6
# 3116    WI      7.5
# 3117    WI      7.8
# 3118    WY     14.4
# 3119    WY     13.2
# 3120    WY      7.9
# 3121    WY     12.2
# 3122    WY     10.5
# 3123    WY      8.5
# ...

# %%
health_data.loc[0,:]
# Out:
# County                Autauga
# State                      AL
# Population_Density         82
# Poverty                  10.4
# Infant_Mortality          5.9
# Suicide                  16.6
# Total_Births             3048
# Total_Deaths             1867
# Name: 0, dtype: object

# %%
health_data.loc[0,['Population_Density' , 'Poverty']]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
health_data.iloc[0,2:4]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
health_data[(health_data['State']=='AL') | (health_data['State'] == 'TX')]
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 0        Autauga    AL                  82     10.4               5.9
# 1        Baldwin    AL                 102     10.2               7.1
# 2        Barbour    AL                  32     22.1               7.1
# 3           Bibb    AL                  35     16.8               9.8
# 4         Blount    AL                  86     11.9               9.0
# 5        Bullock    AL                  18     26.2              13.3
# 6         Butler    AL                  27     20.0               5.8
# 7        Calhoun    AL                 184     16.4               9.5
# 8       Chambers    AL                  59     16.2               7.5
# 9       Cherokee    AL                  44     15.2               7.4
# 10       Chilton    AL                  60     14.9              10.5
# 11       Choctaw    AL                  16     18.7              10.8
# ...

# %%
# cleaning suicide values
health_data['Suicide'].replace(-1111.1,0,inplace=True)
health_data.head(6)
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
# 2  Barbour    AL                  32     22.1               7.1     10.3
# 3     Bibb    AL                  35     16.8               9.8     14.8
# 4   Blount    AL                  86     11.9               9.0     14.4
# 5  Bullock    AL                  18     26.2              13.3      0.0
#
#    Total_Births  Total_Deaths
# 0          3048          1867
# 1          5471          4388
# 2          1835          1538
# 3          2801          2012
# 4          3318          2453
# 5          1604          1381

# %%
a_tuple = (1,2)
a_tuple
# Out:
# (1, 2)

# %%
a_list = [1,2]
type(a_list)
# Out:
# list

# %%
nested_list = [(1,2),(3,4)]
nested_list
# Out:
# [(1, 2), (3, 4)]

# %%
data_for_al = health_data.loc[health_data['State'] == 'AL',['Population_Density', 'Poverty']]
data_for_al.head()
# Out:
#    Population_Density  Poverty
# 0                  82     10.4
# 1                 102     10.2
# 2                  32     22.1
# 3                  35     16.8
# 4                  86     11.9

# %%
lst = [tuple(x) for x in data_for_al.values]
lst
# Out:
# [(82.0, 10.4),
#  (102.0, 10.199999999999999),
#  (32.0, 22.100000000000001),
#  (35.0, 16.800000000000001),
#  (86.0, 11.9),
#  (18.0, 26.199999999999999),
#  (27.0, 20.0),
#  (184.0, 16.399999999999999),
#  (59.0, 16.199999999999999),
#  (44.0, 15.199999999999999),
#  (60.0, 14.9),
#  (16.0, 18.699999999999999),
#  (22.0, 19.199999999999999),
#  (23.0, 14.0),
#  (26.0, 14.0),
#  (67.0, 13.699999999999999),
#  (92.0, 14.0),
#  (16.0, 22.0),
#  (17.0, 13.4),
#  (36.0, 17.5),
#  (23.0, 17.600000000000001),
#  (108.0, 13.300000000000001),
#  (87.0, 15.800000000000001),
#  (45.0, 25.0),
#  (86.0, 15.1),
#  (119.0, 12.5),
#  (40.0, 18.600000000000001),
#  (193.0, 15.699999999999999),
#  (29.0, 16.100000000000001),
#  (48.0, 17.399999999999999),
#  (45.0, 17.600000000000001),
#  (15.0, 24.899999999999999),
#  (28.0, 20.600000000000001),
#  (30.0, 16.300000000000001),
#  (162.0, 15.300000000000001),
#  (50.0, 14.5),
#  (591.0, 14.4),
#  (25.0, 16.100000000000001),
#  (131.0, 15.6),
# ...

# %%
# creating scatter plot
scatter_plot = pygal.XY(stroke=False)
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
#Adding Title to the graph
scatter_plot = pygal.XY(stroke=False)
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
#Adding lobel to x & y axis
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.add('AL',lst)
SVG(scatter_plot.render())

# %%
data_for_tx = health_data.loc[health_data['State'] == 'TX',['Population_Density', 'Poverty']]
data_for_tx.head()
# Out:
#       Population_Density  Poverty
# 2521                  53     20.1
# 2522                   8     15.0
# 2523                 102     17.3
# 2524                  98     18.5
# 2525                  10      9.1

# %%
lst2 = [tuple(x) for x in data_for_tx.values]
lst
# Out:
# [(82.0, 10.4),
#  (102.0, 10.199999999999999),
#  (32.0, 22.100000000000001),
#  (35.0, 16.800000000000001),
#  (86.0, 11.9),
#  (18.0, 26.199999999999999),
#  (27.0, 20.0),
#  (184.0, 16.399999999999999),
#  (59.0, 16.199999999999999),
#  (44.0, 15.199999999999999),
#  (60.0, 14.9),
#  (16.0, 18.699999999999999),
#  (22.0, 19.199999999999999),
#  (23.0, 14.0),
#  (26.0, 14.0),
#  (67.0, 13.699999999999999),
#  (92.0, 14.0),
#  (16.0, 22.0),
#  (17.0, 13.4),
#  (36.0, 17.5),
#  (23.0, 17.600000000000001),
#  (108.0, 13.300000000000001),
#  (87.0, 15.800000000000001),
#  (45.0, 25.0),
#  (86.0, 15.1),
#  (119.0, 12.5),
#  (40.0, 18.600000000000001),
#  (193.0, 15.699999999999999),
#  (29.0, 16.100000000000001),
#  (48.0, 17.399999999999999),
#  (45.0, 17.600000000000001),
#  (15.0, 24.899999999999999),
#  (28.0, 20.600000000000001),
#  (30.0, 16.300000000000001),
#  (162.0, 15.300000000000001),
#  (50.0, 14.5),
#  (591.0, 14.4),
#  (25.0, 16.100000000000001),
#  (131.0, 15.6),
# ...

# %%
scatter_plot = pygal.XY(stroke=False)
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())

# %%
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())

# %%
# for loop
for i in range(0,6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(0,6,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
# changing the x-axis
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.x_labels = (num for num in range(0,2000,100))
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-63b344a0ad0a> in <module>()
#       3 scatter_plot.title = 'Correlation of Population Density and Poverty'
#       4 scatter_plot.x_labels = (num for num in range(0,2000,100))
# ----> 5 fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#       6 scatter_plot.add('AL',lst)
#       7 scatter_plot.add('TX',lst2)
#
# NameError: name 'plt' is not defined

# %%
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.x_labels = (num for num in range(0,2000,100))
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
SVG(scatter_plot.render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-ca9c63e682c0> in <module>()
#       4 scatter_plot.add('AL',lst)
#       5 scatter_plot.add('TX',lst2)
# ----> 6 fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#       7 SVG(scatter_plot.render())
#
# NameError: name 'plt' is not defined

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.x_labels = (num for num in range(0,2000,100))
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-d414fe0a5a19> in <module>()
# ----> 1 fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
#       2 scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
#       3 scatter_plot.title = 'Correlation of Population Density and Poverty'
#       4 scatter_plot.x_labels = (num for num in range(0,2000,100))
#       5 scatter_plot.add('AL',lst)
#
# NameError: name 'plt' is not defined

# %%
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty',width =5024 , height = 2000,dpi = 3000)
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.x_labels = (num for num in range(0,2000,100))
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())

# %%
scatter_plot = pygal.XY(stroke=True, x_title='Population_Density',y_title='Poverty')
scatter_plot.title = 'Correlation of Population Density and Poverty'
scatter_plot.x_labels = (num for num in range(0,2000,100))
scatter_plot.add('AL',lst)
scatter_plot.add('TX',lst2)
SVG(scatter_plot.render())

# %%
def mean_of_column (state_name, column_name):

    state_df = health_data.loc[health_data['State'] == state_name,[column_name]]

    return state_df[column_name].mean()

# %%
# vertical bars
bar_chart = pygal.Bar()
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())

# %%
# horizontal bars
bar_chart = pygal.HorizontalBar()
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())

# %%
# horizontal bars
bar_chart = pygal.HorizontalBar(legend_at_bottom=True, legend_at_bottom_columns=11)
bar_chart.title = 'Mean of Poverty across all states'
for state in list(health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())
